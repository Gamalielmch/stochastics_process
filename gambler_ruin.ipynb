# %%
import numpy as np
import matplotlib.pyplot as plt

p=[0.8,0.58,0.53,0.5,0.47,0.42,0.35]

p= np.asarray(p)
fig = plt.figure()
for i in range(len(p)):
    q=1-p[i]
    print(q)
    N=20
    u_k=np.zeros((N+1))
    for k in range(N+1):
#         print(k)
        if p[i]==0.5: 
            u_k[k]=(N-k)/N
        else:
            u_k[k]=((q/p[i])**k-(q/p[i])**N)/(1-(q/p[i])**N)
    plt.plot(u_k)
  
plt.ylabel('$u_{k}$')
plt.xlabel('k')

plt.show()
# Out:
# 0.19999999999999996
# 0.42000000000000004
# 0.47
# 0.5
# 0.53
# 0.5800000000000001
# 0.65

# %%
number_of_simulations = 200

# Create an array of wins of length equal to number_of_simulations
wins = [False] * number_of_simulations

# Fair Game
p= 0.5
N=50
k=40
ki=np.zeros((number_of_simulations+1))

i=0
while i < number_of_simulations and k >= 0 and k<N+1 :

    if p==0.5: 
        pn =(N-k)/N
    else:
        pn =((q/p[i])**k-(q/p[i])**N)/(1-(q/p[i])**N)
    #print(p)
    p1_lose = np.random.uniform(0, 1) < pn
    ki[i]=k
    if p1_lose:
        k = k -1
    else:
         k = k + 1
            
    i=i+1
fig = plt.figure()   
plt.plot(ki[0:i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-d68a038625cb> in <module>
#      16         pn =(N-k)/N
#      17     else:
# ---> 18         pn =((q/p[i])**k-(q/p[i])**N)/(1-(q/p[i])**N)
#      19     #print(p)
#      20     p1_lose = np.random.uniform(0, 1) > p
#
# TypeError: 'float' object is not subscriptable

# %%
# Uniform distribution
s= np.random.uniform(0, 1,5000) 
count, bins, ignored = plt.hist(s, 11, density=True)
plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')
plt.show()
